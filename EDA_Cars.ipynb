# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Overview data

# %%
df = pd.read_csv('/Users/viktor_korotkov/Downloads/data.csv')
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# ## Drop odd data

# %%
df.drop(df.columns[[3, 5, 6, 7, 8, 9, 10]], 
    axis = 1, inplace = True
)

# %%
df.rename(columns = {'Engine HP' : 'Horsepower',
    'highway MPG' : 'Highway-mpg', 'city mpg' : 'City-mpg',
    'Vehicle Style' : 'Vehicle-style'
    }, inplace = True
)

# %%
df
# Out:
#           Make       Model  Year  Horsepower  Vehicle-style  Highway-mpg  \
# 0          BMW  1 Series M  2011       335.0          Coupe           26
# 1          BMW    1 Series  2011       300.0    Convertible           28
# 2          BMW    1 Series  2011       300.0          Coupe           28
# 3          BMW    1 Series  2011       230.0          Coupe           28
# 4          BMW    1 Series  2011       230.0    Convertible           28
# ...        ...         ...   ...         ...            ...          ...
# 11909    Acura         ZDX  2012       300.0  4dr Hatchback           23
# 11910    Acura         ZDX  2012       300.0  4dr Hatchback           23
# 11911    Acura         ZDX  2012       300.0  4dr Hatchback           23
# 11912    Acura         ZDX  2013       300.0  4dr Hatchback           23
# 11913  Lincoln      Zephyr  2006       221.0          Sedan           26
#
#        City-mpg  Popularity   MSRP
# 0            19        3916  46135
# 1            19        3916  40650
# 2            20        3916  36350
# 3            18        3916  29450
# 4            18        3916  34500
# ...         ...         ...    ...
# 11909        16         204  46120
# 11910        16         204  56670
# 11911        16         204  50620
# 11912        16         204  50920
# 11913        17          61  28995
#
# [11914 rows x 9 columns]

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#           Make       Model  Year  Horsepower  Vehicle-style  Highway-mpg  \
# 0          BMW  1 Series M  2011       335.0          Coupe           26
# 1          BMW    1 Series  2011       300.0    Convertible           28
# 2          BMW    1 Series  2011       300.0          Coupe           28
# 3          BMW    1 Series  2011       230.0          Coupe           28
# 4          BMW    1 Series  2011       230.0    Convertible           28
# ...        ...         ...   ...         ...            ...          ...
# 11909    Acura         ZDX  2012       300.0  4dr Hatchback           23
# 11910    Acura         ZDX  2012       300.0  4dr Hatchback           23
# 11911    Acura         ZDX  2012       300.0  4dr Hatchback           23
# 11912    Acura         ZDX  2013       300.0  4dr Hatchback           23
# 11913  Lincoln      Zephyr  2006       221.0          Sedan           26
#
#        City-mpg  Popularity   MSRP
# 0            19        3916  46135
# 1            19        3916  40650
# 2            20        3916  36350
# 3            18        3916  29450
# 4            18        3916  34500
# ...         ...         ...    ...
# 11909        16         204  46120
# 11910        16         204  56670
# 11911        16         204  50620
# 11912        16         204  50920
# 11913        17          61  28995
#
# [11081 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Make              0
# Model             0
# Year              0
# Horsepower       69
# Vehicle-style     0
# Highway-mpg       0
# City-mpg          0
# Popularity        0
# MSRP              0
# dtype: int64

# %%
df['Horsepower'].fillna(np.mean(df['Horsepower']), inplace = True)
# Out:
# /var/folders/tp/gy9j_7c501b2yn7ftg_bpxp40000gn/T/ipykernel_59908/1025721330.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Horsepower'].fillna(np.mean(df['Horsepower']), inplace = True)

# %%
df.isnull().sum()
# Out:
# Make             0
# Model            0
# Year             0
# Horsepower       0
# Vehicle-style    0
# Highway-mpg      0
# City-mpg         0
# Popularity       0
# MSRP             0
# dtype: int64

# %% [markdown]
# ## Detect outliers

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
sns.boxplot(df['Horsepower'])
# Out:
# <Axes: ylabel='Horsepower'>

# %%
df = df[df['Horsepower'] < 900]
sns.boxplot(df['City-mpg'])
# Out:
# <Axes: ylabel='City-mpg'>

# %%
sns.boxplot(df['Highway-mpg'])
# Out:
# <Axes: ylabel='Highway-mpg'>

# %%
df = df[df['Highway-mpg'] < 200]
sns.boxplot(df['Popularity'])
# Out:
# <Axes: ylabel='Popularity'>

# %%
df = df[df['Popularity'] < 3500]
sns.boxplot(df['MSRP'])
# Out:
# <Axes: ylabel='MSRP'>

# %%
df = df[df['MSRP'] < 800000]

# %% [markdown]
# ## Univariate analysis

# %%
df.head(5)
# Out:
#     Make Model  Year  Horsepower Vehicle-style  Highway-mpg  City-mpg  \
# 17  Audi   100  1992       172.0         Sedan           24        17
# 19  Audi   100  1992       172.0         Wagon           20        16
# 21  Audi   100  1992       172.0         Sedan           21        16
# 22  Audi   100  1993       172.0         Sedan           24        17
# 23  Audi   100  1993       172.0         Wagon           20        16
#
#     Popularity  MSRP
# 17        3105  2000
# 19        3105  2000
# 21        3105  2000
# 22        3105  2000
# 23        3105  2000

# %% [markdown]
# ### Make

# %%
px.pie(df, names = 'Make')

# %%
df['Make'].describe()
# Out:
# count          9936
# unique           45
# top       Chevrolet
# freq           1078
# Name: Make, dtype: object

# %% [markdown]
# ### Model

# %%
px.pie(df, names = 'Model')

# %%
df['Model'].describe()
# Out:
# count               9936
# unique               823
# top       Silverado 1500
# freq                 156
# Name: Model, dtype: object

# %% [markdown]
# ### Year

# %%
px.box(df, x = 'Year')

# %%
df['Year'].describe()
# Out:
# count    9936.000000
# mean     2010.637983
# std         7.226864
# min      1990.000000
# 25%      2007.000000
# 50%      2015.000000
# 75%      2016.000000
# max      2017.000000
# Name: Year, dtype: float64

# %% [markdown]
# ### Horsepower

# %%
px.box(df, x = 'Horsepower')

# %%
px.histogram(df, x = 'Horsepower')

# %%
df['Horsepower'].describe()
# Out:
# count    9936.000000
# mean      250.122035
# std       109.480677
# min        55.000000
# 25%       170.000000
# 50%       231.000000
# 75%       301.000000
# max       750.000000
# Name: Horsepower, dtype: float64

# %% [markdown]
# ### Vehicle style

# %%
px.pie(df, names = 'Vehicle-style')

# %%
df['Vehicle-style'].describe()
# Out:
# count      9936
# unique       16
# top       Sedan
# freq       2629
# Name: Vehicle-style, dtype: object

# %% [markdown]
# ### Highway mpg

# %%
px.box(df, x = 'Highway-mpg')

# %%
px.histogram(df, x = 'Highway-mpg')

# %%
df['Highway-mpg'].describe()
# Out:
# count    9936.000000
# mean       26.804147
# std         8.388484
# min        12.000000
# 25%        22.000000
# 50%        26.000000
# 75%        30.000000
# max       110.000000
# Name: Highway-mpg, dtype: float64

# %% [markdown]
# ### City mpg

# %%
px.box(df, x = 'City-mpg')

# %%
px.histogram(df, x = 'City-mpg')

# %%
df['City-mpg'].describe()
# Out:
# count    9936.000000
# mean       19.911534
# std         9.122635
# min         7.000000
# 25%        16.000000
# 50%        18.000000
# 75%        22.000000
# max       132.000000
# Name: City-mpg, dtype: float64

# %% [markdown]
# ### Popularity

# %%
px.box(df, x = 'Popularity')

# %%
px.histogram(df, x = 'Popularity', cumulative = True)

# %%
df['Popularity'].describe()
# Out:
# count    9936.000000
# mean     1142.131743
# std       773.639917
# min         2.000000
# 25%       481.000000
# 50%       873.000000
# 75%      1851.000000
# max      3105.000000
# Name: Popularity, dtype: float64

# %% [markdown]
# ### Recommended price

# %%
px.box(df, x = 'MSRP')

# %%
px.histogram(df, x = 'MSRP', log_y = True)

# %%
df['MSRP'].describe()
# Out:
# count      9936.000000
# mean      41463.207428
# std       51906.452450
# min        2000.000000
# 25%       21326.250000
# 50%       30100.000000
# 75%       42600.000000
# max      643330.000000
# Name: MSRP, dtype: float64

# %% [markdown]
# ## Bivariate analysis

# %%
df.head(5)
# Out:
#     Make Model  Year  Horsepower Vehicle-style  Highway-mpg  City-mpg  \
# 17  Audi   100  1992       172.0         Sedan           24        17
# 19  Audi   100  1992       172.0         Wagon           20        16
# 21  Audi   100  1992       172.0         Sedan           21        16
# 22  Audi   100  1993       172.0         Sedan           24        17
# 23  Audi   100  1993       172.0         Wagon           20        16
#
#     Popularity  MSRP
# 17        3105  2000
# 19        3105  2000
# 21        3105  2000
# 22        3105  2000
# 23        3105  2000

# %%
px.histogram(df, x = ['Make', 'Vehicle-style'])

# %%
px.histogram(df, x = ['City-mpg', 'Highway-mpg'])

# %%
sns.pairplot(df)
plt.show()
